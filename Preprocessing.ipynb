# %%
import numpy as np
import pandas as pd

# %%
# Upload the dataset
listing_path = 'listings.csv'
listing_data = pd.read_csv(listing_path)
print(listing_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8021 entries, 0 to 8020
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            8021 non-null   int64
#  1   listing_url                                   8021 non-null   object
#  2   scrape_id                                     8021 non-null   int64
#  3   last_scraped                                  8021 non-null   object
#  4   source                                        8021 non-null   object
#  5   name                                          8021 non-null   object
#  6   description                                   7663 non-null   object
#  7   neighborhood_overview                         2757 non-null   object
#  8   picture_url                                   8019 non-null   object
#  9   host_id                                       8021 non-null   int64
#  10  host_url                                      8021 non-null   object
#  11  host_name                                     8021 non-null   object
#  12  host_since                                    8021 non-null   object
#  13  host_location                                 6267 non-null   object
#  14  host_about                                    2985 non-null   object
#  15  host_response_time                            5853 non-null   object
#  16  host_response_rate                            5853 non-null   object
#  17  host_acceptance_rate                          6431 non-null   object
#  18  host_is_superhost                             7952 non-null   object
#  19  host_thumbnail_url                            8021 non-null   object
#  20  host_picture_url                              8021 non-null   object
#  21  host_neighbourhood                            1970 non-null   object
#  22  host_listings_count                           8021 non-null   int64
#  23  host_total_listings_count                     8021 non-null   int64
#  24  host_verifications                            8021 non-null   object
#  25  host_has_profile_pic                          8021 non-null   object
#  26  host_identity_verified                        8021 non-null   object
#  27  neighbourhood                                 2757 non-null   object
#  28  neighbourhood_cleansed                        8021 non-null   object
#  29  neighbourhood_group_cleansed                  0 non-null      float64
#  30  latitude                                      8021 non-null   float64
#  31  longitude                                     8021 non-null   float64
#  32  property_type                                 8021 non-null   object
#  33  room_type                                     8021 non-null   object
#  34  accommodates                                  8021 non-null   int64
#  35  bathrooms                                     5819 non-null   float64
#  36  bathrooms_text                                8010 non-null   object
#  37  bedrooms                                      7306 non-null   float64
#  38  beds                                          5820 non-null   float64
#  39  amenities                                     8021 non-null   object
#  40  price                                         5826 non-null   object
#  41  minimum_nights                                8021 non-null   int64
#  42  maximum_nights                                8021 non-null   int64
#  43  minimum_minimum_nights                        8021 non-null   int64
#  44  maximum_minimum_nights                        8021 non-null   int64
#  45  minimum_maximum_nights                        8021 non-null   int64
#  46  maximum_maximum_nights                        8021 non-null   int64
#  47  minimum_nights_avg_ntm                        8021 non-null   float64
#  48  maximum_nights_avg_ntm                        8021 non-null   float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              7712 non-null   object
#  51  availability_30                               8021 non-null   int64
#  52  availability_60                               8021 non-null   int64
#  53  availability_90                               8021 non-null   int64
#  54  availability_365                              8021 non-null   int64
#  55  calendar_last_scraped                         8021 non-null   object
#  56  number_of_reviews                             8021 non-null   int64
#  57  number_of_reviews_ltm                         8021 non-null   int64
#  58  number_of_reviews_l30d                        8021 non-null   int64
#  59  first_review                                  5950 non-null   object
#  60  last_review                                   5950 non-null   object
#  61  review_scores_rating                          5950 non-null   float64
#  62  review_scores_accuracy                        5950 non-null   float64
#  63  review_scores_cleanliness                     5950 non-null   float64
#  64  review_scores_checkin                         5950 non-null   float64
#  65  review_scores_communication                   5950 non-null   float64
#  66  review_scores_location                        5950 non-null   float64
#  67  review_scores_value                           5950 non-null   float64
#  68  license                                       42 non-null     object
#  69  instant_bookable                              8021 non-null   object
#  70  calculated_host_listings_count                8021 non-null   int64
#  71  calculated_host_listings_count_entire_homes   8021 non-null   int64
#  72  calculated_host_listings_count_private_rooms  8021 non-null   int64
#  73  calculated_host_listings_count_shared_rooms   8021 non-null   int64
#  74  reviews_per_month                             5950 non-null   float64
# dtypes: float64(17), int64(23), object(35)
# memory usage: 4.6+ MB
# None

# %%
# Drop rows where property_type has less than 35 value counts
property_counts = listing_data['property_type'].value_counts()
print(listing_data.shape)
to_keep = property_counts[property_counts >= 35].index
listing_data = listing_data[listing_data['property_type'].isin(to_keep)]
print(listing_data.shape)
# Out:
# (8021, 75)
# (7749, 75)

# %%
columns_to_drop = [
    'listing_url', 'source' ,'scrape_id', 'host_url', 'picture_url', 'host_thumbnail_url', 
    'host_picture_url', 'last_scraped', 'calendar_last_scraped', 'calendar_updated', 
    'neighbourhood_group_cleansed', 'host_about', 'host_since', 'host_location', 
    'host_name', 'host_response_time', 'host_response_rate', 'host_acceptance_rate', 
    'host_neighbourhood', 'host_has_profile_pic', 'license', 'minimum_minimum_nights', 
    'maximum_minimum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights', 
    'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'host_total_listings_count', 'host_verifications', 'neighbourhood',
    'last_review', 'first_review', 'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms',
    'calculated_host_listings_count_shared_rooms', 'neighborhood_overview', 'room_type', 'name','host_id', 'id'
]

# Drop features that are not useful for the analysis
listing_data = listing_data.drop(columns=columns_to_drop)
print(listing_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7749 entries, 0 to 8020
# Data columns (total 35 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   description                     7407 non-null   object
#  1   host_is_superhost               7680 non-null   object
#  2   host_listings_count             7749 non-null   int64
#  3   host_identity_verified          7749 non-null   object
#  4   neighbourhood_cleansed          7749 non-null   object
#  5   latitude                        7749 non-null   float64
#  6   longitude                       7749 non-null   float64
#  7   property_type                   7749 non-null   object
#  8   accommodates                    7749 non-null   int64
#  9   bathrooms                       5625 non-null   float64
#  10  bathrooms_text                  7741 non-null   object
#  11  bedrooms                        7052 non-null   float64
#  12  beds                            5625 non-null   float64
#  13  amenities                       7749 non-null   object
#  14  price                           5631 non-null   object
#  15  minimum_nights                  7749 non-null   int64
#  16  maximum_nights                  7749 non-null   int64
#  17  has_availability                7445 non-null   object
#  18  availability_30                 7749 non-null   int64
#  19  availability_60                 7749 non-null   int64
#  20  availability_90                 7749 non-null   int64
#  21  availability_365                7749 non-null   int64
#  22  number_of_reviews               7749 non-null   int64
#  23  number_of_reviews_ltm           7749 non-null   int64
#  24  number_of_reviews_l30d          7749 non-null   int64
#  25  review_scores_rating            5731 non-null   float64
#  26  review_scores_accuracy          5731 non-null   float64
#  27  review_scores_cleanliness       5731 non-null   float64
#  28  review_scores_checkin           5731 non-null   float64
#  29  review_scores_communication     5731 non-null   float64
#  30  review_scores_location          5731 non-null   float64
#  31  review_scores_value             5731 non-null   float64
#  32  instant_bookable                7749 non-null   object
#  33  calculated_host_listings_count  7749 non-null   int64
#  34  reviews_per_month               5731 non-null   float64
# dtypes: float64(13), int64(12), object(10)
# memory usage: 2.1+ MB
# None

# %%
# Show percentage of null values in each column
null_percentage = listing_data.isnull().mean() * 100
print(null_percentage)
print(listing_data.shape)
# Out:
# description                        4.413473
# host_is_superhost                  0.890437
# host_listings_count                0.000000
# host_identity_verified             0.000000
# neighbourhood_cleansed             0.000000
# latitude                           0.000000
# longitude                          0.000000
# property_type                      0.000000
# accommodates                       0.000000
# bathrooms                         27.409988
# bathrooms_text                     0.103239
# bedrooms                           8.994709
# beds                              27.409988
# amenities                          0.000000
# price                             27.332559
# minimum_nights                     0.000000
# maximum_nights                     0.000000
# has_availability                   3.923087
# availability_30                    0.000000
# availability_60                    0.000000
# availability_90                    0.000000
# availability_365                   0.000000
# number_of_reviews                  0.000000
# number_of_reviews_ltm              0.000000
# number_of_reviews_l30d             0.000000
# review_scores_rating              26.042070
# review_scores_accuracy            26.042070
# review_scores_cleanliness         26.042070
# review_scores_checkin             26.042070
# review_scores_communication       26.042070
# review_scores_location            26.042070
# review_scores_value               26.042070
# instant_bookable                   0.000000
# calculated_host_listings_count     0.000000
# reviews_per_month                 26.042070
# dtype: float64
# (7749, 35)

# %%
listing_data['reviews_per_month'] = listing_data['reviews_per_month'].fillna(0)
review_score_columns = ['review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value']
boolean_columns = ['host_is_superhost', 'host_identity_verified', 'has_availability', 'instant_bookable']
# Group by neighbourhood_cleansed and room_type to fill NaN values
listing_data['price'] = listing_data['price'].replace('[€$,]', '', regex=True).astype(float)
listing_data['beds'] = listing_data.groupby(['neighbourhood_cleansed', 'property_type'])['beds'].transform(lambda x: x.fillna(x.mode()[0] if not x.mode().empty else 1))
# Drop rows where all prices in the group are NaN
listing_data = listing_data.groupby(['neighbourhood_cleansed', 'property_type']).filter(lambda x: x['price'].notna().any())                                                            
listing_data['price'] = listing_data.groupby(['neighbourhood_cleansed', 'property_type'])['price'].transform(lambda x: x.fillna(x.mode()[0] if not x.mode().empty else x.mean()))     

# Fill missing review scores with mean
for column in review_score_columns:
    listing_data = listing_data.groupby(['neighbourhood_cleansed', 'property_type']).filter(lambda x: x[review_score_columns].notna().any().all())
    listing_data[column] = listing_data.groupby(['neighbourhood_cleansed', 'property_type'])[column].transform(lambda x: x.fillna(x.mean()))

# Transform boolean columns
for column in boolean_columns:
    listing_data[column] = listing_data[column].map({'t': 1, 'f': 0})

# Split bathrooms_text into num_bathrooms and type_bathroom
listing_data[['num_bathrooms', 'type_bathroom']] = listing_data['bathrooms_text'].str.extract(r'(\d*\.?\d+)\s*(.*)')
listing_data = listing_data.dropna(subset=['type_bathroom'])
listing_data['num_bathrooms'] = listing_data['num_bathrooms'].astype(float)

# Fill missing bathrooms with num_bathrooms and vice versa
listing_data['bathrooms'] = listing_data.apply(lambda row: row['num_bathrooms'] if pd.isna(row['bathrooms']) and not pd.isna(row['num_bathrooms']) else row['bathrooms'], axis=1)
listing_data['num_bathrooms'] = listing_data.apply(lambda row: row['bathrooms'] if pd.isna(row['num_bathrooms']) and not pd.isna(row['bathrooms']) else row['num_bathrooms'], axis=1)

# Drop rows where both bathrooms and num_bathrooms are NaN
listing_data = listing_data.dropna(subset=['bathrooms', 'num_bathrooms'], how='all')

# Transform type_bathroom values
listing_data['type_bathroom'] = listing_data['type_bathroom'].replace({'bath': 'private', 'private bath': 'private', 'shared bath': 'shared'})

# Fill missing bedrooms with default value 1
listing_data['bedrooms'] = listing_data['bedrooms'].fillna(1)

# %%
# Fill NaN values in 'host_is_superhost' with 0 (False)
listing_data['host_is_superhost'] = listing_data['host_is_superhost'].fillna(0)

# Fill NaN values in 'description' with an empty string
listing_data['description'] = listing_data['description'].fillna("")

# Set 'has_availability' to 1 (True) if 'availability_30' is greater than 25, otherwise 0 (False)
listing_data['has_availability'] = listing_data['availability_30'].apply(lambda x: 1 if x >= 25 else 0)

# %%
print(listing_data['price'].isnull().sum())
# Out:
# 0

# %%
null_percentage = listing_data.isnull().mean() * 100
print(null_percentage)
print(listing_data.shape)
# Out:
# description                       0.0
# host_is_superhost                 0.0
# host_listings_count               0.0
# host_identity_verified            0.0
# neighbourhood_cleansed            0.0
# latitude                          0.0
# longitude                         0.0
# property_type                     0.0
# accommodates                      0.0
# bathrooms                         0.0
# bathrooms_text                    0.0
# bedrooms                          0.0
# beds                              0.0
# amenities                         0.0
# price                             0.0
# minimum_nights                    0.0
# maximum_nights                    0.0
# has_availability                  0.0
# availability_30                   0.0
# availability_60                   0.0
# availability_90                   0.0
# availability_365                  0.0
# number_of_reviews                 0.0
# number_of_reviews_ltm             0.0
# number_of_reviews_l30d            0.0
# review_scores_rating              0.0
# review_scores_accuracy            0.0
# review_scores_cleanliness         0.0
# review_scores_checkin             0.0
# review_scores_communication       0.0
# review_scores_location            0.0
# review_scores_value               0.0
# instant_bookable                  0.0
# calculated_host_listings_count    0.0
# reviews_per_month                 0.0
# num_bathrooms                     0.0
# type_bathroom                     0.0
# dtype: float64
# (7600, 37)

# %%
# Compute the 99th percentile of the price for each neighbourhood and property type
price_99_percentile = listing_data.groupby(['neighbourhood_cleansed', 'property_type'])['price'].quantile(0.99)

# Filter out the rows where the price is higher than 99th percentile
listing_data = listing_data[listing_data.apply(
    lambda row: row['price'] <= price_99_percentile.loc[row['neighbourhood_cleansed'], row['property_type']],
    axis=1
)]
print(f"{listing_data.shape}")
# Out:
# (7391, 37)

# %%
import ast
# List of features to check for
features = ['wifi', 'pool', 'gym', 'bluetooth', 'refrigerator', 'stove', 'oven', 'TV', 'grill', 'parking', 'garage', 'kitchen', 'fireplace', 'housekeeping', 'console', 'exercise', 'coffee maker', 'clothing storage']
listing_data['amenities'] = listing_data['amenities'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
# Function to check if a feature is present in the amenities
def has_feature(amenities, feature):
    return int(any(feature.lower() in amenity.lower() for amenity in amenities))

# Create new features
for feature in features:
    listing_data[f'has_{feature.replace(" ", "_")}'] = listing_data['amenities'].apply(lambda x: has_feature(x, feature))

# Count the number of rows for each new feature
feature_counts = {f'has_{feature.replace(" ", "_")}': listing_data[f'has_{feature.replace(" ", "_")}'].sum() for feature in features}
# Print the feature counts sorted in decreasing order
sorted_feature_counts = dict(sorted(feature_counts.items(), key=lambda item: item[1], reverse=True))
print(sorted_feature_counts)
# Out:
# {'has_wifi': np.int64(7002), 'has_kitchen': np.int64(6742), 'has_TV': np.int64(4823), 'has_parking': np.int64(4428), 'has_refrigerator': np.int64(4421), 'has_stove': np.int64(3596), 'has_coffee_maker': np.int64(3357), 'has_oven': np.int64(3151), 'has_clothing_storage': np.int64(2728), 'has_grill': np.int64(659), 'has_exercise': np.int64(584), 'has_bluetooth': np.int64(329), 'has_garage': np.int64(272), 'has_fireplace': np.int64(214), 'has_console': np.int64(177), 'has_pool': np.int64(159), 'has_gym': np.int64(158), 'has_housekeeping': np.int64(78)}

# %%
# Drop the 'amenities' column
listing_data = listing_data.drop(columns=['amenities'])
print(listing_data.columns)
# Out:
# Index(['description', 'host_is_superhost', 'host_listings_count',
#        'host_identity_verified', 'neighbourhood_cleansed', 'latitude',
#        'longitude', 'property_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'price', 'minimum_nights',
#        'maximum_nights', 'has_availability', 'availability_30',
#        'availability_60', 'availability_90', 'availability_365',
#        'number_of_reviews', 'number_of_reviews_ltm', 'number_of_reviews_l30d',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'instant_bookable',
#        'calculated_host_listings_count', 'reviews_per_month', 'num_bathrooms',
#        'type_bathroom', 'has_wifi', 'has_pool', 'has_gym', 'has_bluetooth',
#        'has_refrigerator', 'has_stove', 'has_oven', 'has_TV', 'has_grill',
#        'has_parking', 'has_garage', 'has_kitchen', 'has_fireplace',
#        'has_housekeeping', 'has_console', 'has_exercise', 'has_coffee_maker',
#        'has_clothing_storage'],
#       dtype='object')

# %%
columns_to_check = [
    'number_of_reviews',
    'number_of_reviews_ltm',
    'number_of_reviews_l30d',
    'review_scores_rating',
    'review_scores_accuracy',
    'review_scores_cleanliness',
    'review_scores_checkin',
    'review_scores_communication',
    'review_scores_location',
    'review_scores_value'
]

results = {}

# Check for negative values and values equal to 0 and store the results in the dictionary in order to print them

for column in columns_to_check:
    if column in listing_data.columns: 
        anomalies = {
            'negative_values': (listing_data[column] > 0).sum(),  
            'greater_than_5': (listing_data[column] == 0).sum(), 
        }
        results[column] = anomalies
    else:
        results[column] = 'Column not found in the dataset'

for column, anomalies in results.items():
    print(f"{column}:")
    if isinstance(anomalies, dict):
        print(f"  Greater than 0: {anomalies['negative_values']}")
        print(f"  Equal to 0 : {anomalies['greater_than_5']}")
    else:
        print(f"  {anomalies}")
    print()
# Out:
# number_of_reviews:
#   Greater than 0: 5496
#   Equal to 0 : 1895
#
# number_of_reviews_ltm:
#   Greater than 0: 4152
#   Equal to 0 : 3239
#
# number_of_reviews_l30d:
#   Greater than 0: 2000
#   Equal to 0 : 5391
#
# review_scores_rating:
#   Greater than 0: 7391
#   Equal to 0 : 0
#
# review_scores_accuracy:
#   Greater than 0: 7391
#   Equal to 0 : 0
#
# review_scores_cleanliness:
#   Greater than 0: 7391
#   Equal to 0 : 0
#
# review_scores_checkin:
#   Greater than 0: 7390
#   Equal to 0 : 1
#
# review_scores_communication:
#   Greater than 0: 7391
#   Equal to 0 : 0
#
# review_scores_location:
#   Greater than 0: 7391
#   Equal to 0 : 0
#
# review_scores_value:
#   Greater than 0: 7391
#   Equal to 0 : 0

# %%
# Transform the columns to boolean values
listing_data['number_of_reviews_ltm'] = listing_data['number_of_reviews_ltm'] > 0
listing_data['number_of_reviews_l30d'] = listing_data['number_of_reviews_l30d'] > 0

# %%
score_columns = [
    'review_scores_rating',
    'review_scores_accuracy',
    'review_scores_cleanliness',
    'review_scores_checkin',
    'review_scores_communication',
    'review_scores_location',
    'review_scores_value'
]

# Compute the mean of the review scores
listing_data['review_scores_mean'] = listing_data[score_columns].mean(axis=1)
# Drop the individual review scores
listing_data.drop(columns=score_columns, inplace=True)

# %%
# Drop rows with NaN values in 'review_scores_mean'
listing_data = listing_data.drop(columns=['bathrooms', 'bathrooms_text'])
print(listing_data[['num_bathrooms', 'type_bathroom']])
# Out:
#       num_bathrooms type_bathroom
# 0               1.0       private
# 1               1.0       private
# 2               1.0       private
# 3               1.0       private
# 4               1.0        shared
# ...             ...           ...
# 8015            1.0       private
# 8016            1.0       private
# 8018            1.0       private
# 8019            1.0        shared
# 8020            1.0        shared
#
# [7391 rows x 2 columns]

# %%
# One-hot encoding for neighbourhood_cleansed and property_type
listing_data = pd.get_dummies(listing_data, columns=['neighbourhood_cleansed', 'property_type',  'type_bathroom'], drop_first=True)
print(listing_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7391 entries, 0 to 8020
# Data columns (total 81 columns):
#  #   Column                                                                         Non-Null Count  Dtype
# ---  ------                                                                         --------------  -----
#  0   description                                                                    7391 non-null   object
#  1   host_is_superhost                                                              7391 non-null   float64
#  2   host_listings_count                                                            7391 non-null   int64
#  3   host_identity_verified                                                         7391 non-null   int64
#  4   latitude                                                                       7391 non-null   float64
#  5   longitude                                                                      7391 non-null   float64
#  6   accommodates                                                                   7391 non-null   int64
#  7   bedrooms                                                                       7391 non-null   float64
#  8   beds                                                                           7391 non-null   float64
#  9   price                                                                          7391 non-null   float64
#  10  minimum_nights                                                                 7391 non-null   int64
#  11  maximum_nights                                                                 7391 non-null   int64
#  12  has_availability                                                               7391 non-null   int64
#  13  availability_30                                                                7391 non-null   int64
#  14  availability_60                                                                7391 non-null   int64
#  15  availability_90                                                                7391 non-null   int64
#  16  availability_365                                                               7391 non-null   int64
#  17  number_of_reviews                                                              7391 non-null   int64
#  18  number_of_reviews_ltm                                                          7391 non-null   bool
#  19  number_of_reviews_l30d                                                         7391 non-null   bool
#  20  instant_bookable                                                               7391 non-null   int64
#  21  calculated_host_listings_count                                                 7391 non-null   int64
#  22  reviews_per_month                                                              7391 non-null   float64
#  23  num_bathrooms                                                                  7391 non-null   float64
#  24  has_wifi                                                                       7391 non-null   int64
#  25  has_pool                                                                       7391 non-null   int64
#  26  has_gym                                                                        7391 non-null   int64
#  27  has_bluetooth                                                                  7391 non-null   int64
#  28  has_refrigerator                                                               7391 non-null   int64
#  29  has_stove                                                                      7391 non-null   int64
#  30  has_oven                                                                       7391 non-null   int64
#  31  has_TV                                                                         7391 non-null   int64
#  32  has_grill                                                                      7391 non-null   int64
#  33  has_parking                                                                    7391 non-null   int64
#  34  has_garage                                                                     7391 non-null   int64
#  35  has_kitchen                                                                    7391 non-null   int64
#  36  has_fireplace                                                                  7391 non-null   int64
#  37  has_housekeeping                                                               7391 non-null   int64
#  38  has_console                                                                    7391 non-null   int64
#  39  has_exercise                                                                   7391 non-null   int64
#  40  has_coffee_maker                                                               7391 non-null   int64
#  41  has_clothing_storage                                                           7391 non-null   int64
#  42  review_scores_mean                                                             7391 non-null   float64
#  43  neighbourhood_cleansed_Altstadt-Lehel                                          7391 non-null   bool
#  44  neighbourhood_cleansed_Au-Haidhausen                                           7391 non-null   bool
#  45  neighbourhood_cleansed_Aubing-Lochhausen-Langwied                              7391 non-null   bool
#  46  neighbourhood_cleansed_Berg am Laim                                            7391 non-null   bool
#  47  neighbourhood_cleansed_Bogenhausen                                             7391 non-null   bool
#  48  neighbourhood_cleansed_Feldmoching-Hasenbergl                                  7391 non-null   bool
#  49  neighbourhood_cleansed_Hadern                                                  7391 non-null   bool
#  50  neighbourhood_cleansed_Laim                                                    7391 non-null   bool
#  51  neighbourhood_cleansed_Ludwigsvorstadt-Isarvorstadt                            7391 non-null   bool
#  52  neighbourhood_cleansed_Maxvorstadt                                             7391 non-null   bool
#  53  neighbourhood_cleansed_Milbertshofen-Am Hart                                   7391 non-null   bool
#  54  neighbourhood_cleansed_Moosach                                                 7391 non-null   bool
#  55  neighbourhood_cleansed_Neuhausen-Nymphenburg                                   7391 non-null   bool
#  56  neighbourhood_cleansed_Obergiesing                                             7391 non-null   bool
#  57  neighbourhood_cleansed_Pasing-Obermenzing                                      7391 non-null   bool
#  58  neighbourhood_cleansed_Ramersdorf-Perlach                                      7391 non-null   bool
#  59  neighbourhood_cleansed_Schwabing-Freimann                                      7391 non-null   bool
#  60  neighbourhood_cleansed_Schwabing-West                                          7391 non-null   bool
#  61  neighbourhood_cleansed_Schwanthalerhöhe                                        7391 non-null   bool
#  62  neighbourhood_cleansed_Sendling                                                7391 non-null   bool
#  63  neighbourhood_cleansed_Sendling-Westpark                                       7391 non-null   bool
#  64  neighbourhood_cleansed_Thalkirchen-Obersendling-Forstenried-Fürstenried-Solln  7391 non-null   bool
#  65  neighbourhood_cleansed_Tudering-Riem                                           7391 non-null   bool
#  66  neighbourhood_cleansed_Untergiesing-Harlaching                                 7391 non-null   bool
#  67  property_type_Entire home                                                      7391 non-null   bool
#  68  property_type_Entire loft                                                      7391 non-null   bool
#  69  property_type_Entire rental unit                                               7391 non-null   bool
#  70  property_type_Entire serviced apartment                                        7391 non-null   bool
#  71  property_type_Private room in condo                                            7391 non-null   bool
#  72  property_type_Private room in home                                             7391 non-null   bool
#  73  property_type_Private room in rental unit                                      7391 non-null   bool
#  74  property_type_Private room in townhouse                                        7391 non-null   bool
#  75  property_type_Room in boutique hotel                                           7391 non-null   bool
#  76  property_type_Room in hotel                                                    7391 non-null   bool
#  77  property_type_Shared room in rental unit                                       7391 non-null   bool
#  78  type_bathroom_private                                                          7391 non-null   bool
#  79  type_bathroom_shared                                                           7391 non-null   bool
#  80  type_bathroom_shared baths                                                     7391 non-null   bool
# dtypes: bool(40), float64(9), int64(31), object(1)
# memory usage: 2.7+ MB
# None

# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Load your dataset
# Initialize the sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Function to analyze sentiment
def get_sentiment(text):
    sentiment_score = analyzer.polarity_scores(text)
    return sentiment_score['compound']  # Returns the sentiment score

# Apply the sentiment analysis function to the description column
# listing_data['sentiment_score'] = listing_data['description'].apply(get_sentiment)
listing_data = listing_data.drop(columns=['description'])

# We tried to add sentiment_score feature, but we did not obtain any significant improvement in the models performance, so we discarded it.

# %%
from sklearn.preprocessing import StandardScaler

# List of columns to normalize
columns_to_normalize = [
    'host_listings_count', 'latitude', 'longitude', 'accommodates', 'bedrooms', 'beds', 
    'minimum_nights', 'maximum_nights', 'availability_30', 'availability_60', 
    'availability_90', 'availability_365', 'number_of_reviews', 
    'calculated_host_listings_count', 'reviews_per_month', 'num_bathrooms', 
    'review_scores_mean'
]

# Initialize the StandardScaler
scaler = StandardScaler()

# Apply z-score normalization
listing_data[columns_to_normalize] = scaler.fit_transform(listing_data[columns_to_normalize])

# Print mean and standard deviation for each feature
for column in columns_to_normalize:
    mean = listing_data[column].mean()
    std = listing_data[column].std()
    print(f"{column}: mean = {mean:.2f}, std = {std:.2f}")

print(listing_data[['latitude', 'longitude']])
# Out:
# host_listings_count: mean = -0.00, std = 1.00
# latitude: mean = 0.00, std = 1.00
# longitude: mean = 0.00, std = 1.00
# accommodates: mean = -0.00, std = 1.00
# bedrooms: mean = -0.00, std = 1.00
# beds: mean = -0.00, std = 1.00
# minimum_nights: mean = 0.00, std = 1.00
# maximum_nights: mean = 0.00, std = 1.00
# availability_30: mean = -0.00, std = 1.00
# availability_60: mean = -0.00, std = 1.00
# availability_90: mean = 0.00, std = 1.00
# availability_365: mean = 0.00, std = 1.00
# number_of_reviews: mean = -0.00, std = 1.00
# calculated_host_listings_count: mean = -0.00, std = 1.00
# reviews_per_month: mean = -0.00, std = 1.00
# num_bathrooms: mean = 0.00, std = 1.00
# review_scores_mean: mean = -0.00, std = 1.00
#       latitude  longitude
# 0    -0.967912  -1.513552
# 1    -0.741470   1.550787
# 2     0.481865   0.044699
# 3    -0.043762  -2.003714
# 4    -1.233073  -0.731322
# ...        ...        ...
# 8015  2.745108  -0.104148
# 8016  0.531808   0.013467
# 8018  1.765100  -0.242996
# 8019 -0.015604  -0.412758
# 8020  0.413424  -0.142631
#
# [7391 rows x 2 columns]

# %%
# check for NaN values
columns_with_nan = listing_data.columns[listing_data.isna().any()]

for column in columns_with_nan:
    num_nan = listing_data[column].isna().sum()
    print(f"'{column}': {num_nan} NaN values")

# %%
listing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7391 entries, 0 to 8020
# Data columns (total 80 columns):
#  #   Column                                                                         Non-Null Count  Dtype
# ---  ------                                                                         --------------  -----
#  0   host_is_superhost                                                              7391 non-null   float64
#  1   host_listings_count                                                            7391 non-null   float64
#  2   host_identity_verified                                                         7391 non-null   int64
#  3   latitude                                                                       7391 non-null   float64
#  4   longitude                                                                      7391 non-null   float64
#  5   accommodates                                                                   7391 non-null   float64
#  6   bedrooms                                                                       7391 non-null   float64
#  7   beds                                                                           7391 non-null   float64
#  8   price                                                                          7391 non-null   float64
#  9   minimum_nights                                                                 7391 non-null   float64
#  10  maximum_nights                                                                 7391 non-null   float64
#  11  has_availability                                                               7391 non-null   int64
#  12  availability_30                                                                7391 non-null   float64
#  13  availability_60                                                                7391 non-null   float64
#  14  availability_90                                                                7391 non-null   float64
#  15  availability_365                                                               7391 non-null   float64
#  16  number_of_reviews                                                              7391 non-null   float64
#  17  number_of_reviews_ltm                                                          7391 non-null   bool
#  18  number_of_reviews_l30d                                                         7391 non-null   bool
#  19  instant_bookable                                                               7391 non-null   int64
#  20  calculated_host_listings_count                                                 7391 non-null   float64
#  21  reviews_per_month                                                              7391 non-null   float64
#  22  num_bathrooms                                                                  7391 non-null   float64
#  23  has_wifi                                                                       7391 non-null   int64
#  24  has_pool                                                                       7391 non-null   int64
#  25  has_gym                                                                        7391 non-null   int64
#  26  has_bluetooth                                                                  7391 non-null   int64
#  27  has_refrigerator                                                               7391 non-null   int64
#  28  has_stove                                                                      7391 non-null   int64
#  29  has_oven                                                                       7391 non-null   int64
#  30  has_TV                                                                         7391 non-null   int64
#  31  has_grill                                                                      7391 non-null   int64
#  32  has_parking                                                                    7391 non-null   int64
#  33  has_garage                                                                     7391 non-null   int64
#  34  has_kitchen                                                                    7391 non-null   int64
#  35  has_fireplace                                                                  7391 non-null   int64
#  36  has_housekeeping                                                               7391 non-null   int64
#  37  has_console                                                                    7391 non-null   int64
#  38  has_exercise                                                                   7391 non-null   int64
#  39  has_coffee_maker                                                               7391 non-null   int64
#  40  has_clothing_storage                                                           7391 non-null   int64
#  41  review_scores_mean                                                             7391 non-null   float64
#  42  neighbourhood_cleansed_Altstadt-Lehel                                          7391 non-null   bool
#  43  neighbourhood_cleansed_Au-Haidhausen                                           7391 non-null   bool
#  44  neighbourhood_cleansed_Aubing-Lochhausen-Langwied                              7391 non-null   bool
#  45  neighbourhood_cleansed_Berg am Laim                                            7391 non-null   bool
#  46  neighbourhood_cleansed_Bogenhausen                                             7391 non-null   bool
#  47  neighbourhood_cleansed_Feldmoching-Hasenbergl                                  7391 non-null   bool
#  48  neighbourhood_cleansed_Hadern                                                  7391 non-null   bool
#  49  neighbourhood_cleansed_Laim                                                    7391 non-null   bool
#  50  neighbourhood_cleansed_Ludwigsvorstadt-Isarvorstadt                            7391 non-null   bool
#  51  neighbourhood_cleansed_Maxvorstadt                                             7391 non-null   bool
#  52  neighbourhood_cleansed_Milbertshofen-Am Hart                                   7391 non-null   bool
#  53  neighbourhood_cleansed_Moosach                                                 7391 non-null   bool
#  54  neighbourhood_cleansed_Neuhausen-Nymphenburg                                   7391 non-null   bool
#  55  neighbourhood_cleansed_Obergiesing                                             7391 non-null   bool
#  56  neighbourhood_cleansed_Pasing-Obermenzing                                      7391 non-null   bool
#  57  neighbourhood_cleansed_Ramersdorf-Perlach                                      7391 non-null   bool
#  58  neighbourhood_cleansed_Schwabing-Freimann                                      7391 non-null   bool
#  59  neighbourhood_cleansed_Schwabing-West                                          7391 non-null   bool
#  60  neighbourhood_cleansed_Schwanthalerhöhe                                        7391 non-null   bool
#  61  neighbourhood_cleansed_Sendling                                                7391 non-null   bool
#  62  neighbourhood_cleansed_Sendling-Westpark                                       7391 non-null   bool
#  63  neighbourhood_cleansed_Thalkirchen-Obersendling-Forstenried-Fürstenried-Solln  7391 non-null   bool
#  64  neighbourhood_cleansed_Tudering-Riem                                           7391 non-null   bool
#  65  neighbourhood_cleansed_Untergiesing-Harlaching                                 7391 non-null   bool
#  66  property_type_Entire home                                                      7391 non-null   bool
#  67  property_type_Entire loft                                                      7391 non-null   bool
#  68  property_type_Entire rental unit                                               7391 non-null   bool
#  69  property_type_Entire serviced apartment                                        7391 non-null   bool
#  70  property_type_Private room in condo                                            7391 non-null   bool
#  71  property_type_Private room in home                                             7391 non-null   bool
#  72  property_type_Private room in rental unit                                      7391 non-null   bool
#  73  property_type_Private room in townhouse                                        7391 non-null   bool
#  74  property_type_Room in boutique hotel                                           7391 non-null   bool
#  75  property_type_Room in hotel                                                    7391 non-null   bool
#  76  property_type_Shared room in rental unit                                       7391 non-null   bool
#  77  type_bathroom_private                                                          7391 non-null   bool
#  78  type_bathroom_shared                                                           7391 non-null   bool
#  79  type_bathroom_shared baths                                                     7391 non-null   bool
# dtypes: bool(40), float64(19), int64(21)
# memory usage: 2.6 MB

# %%
listing_data.to_csv('listings_clean.csv', index=False)
